# %%
# !pip install pandas matplotlib seaborn plotnine ggplot

# %%
from matplotlib import pyplot
import seaborn as sbn
import pandas as pd
from plotnine import ggplot

# %%
from collections import namedtuple
l = sbn.get_dataset_names()
Datasets = namedtuple("Data",l)
sbn_datasets = Datasets(sbn.load_dataset("anagrams"),
sbn.load_dataset("anscombe"),
sbn.load_dataset("attention"),
sbn.load_dataset("brain_networks"),
sbn.load_dataset("car_crashes"),
sbn.load_dataset("diamonds"),
sbn.load_dataset("dots"),
sbn.load_dataset("dowjones"),
sbn.load_dataset("exercise"),
sbn.load_dataset("flights"),
sbn.load_dataset("fmri"),
sbn.load_dataset("geyser"),
sbn.load_dataset("glue"),
sbn.load_dataset("healthexp"),
sbn.load_dataset("iris"),
sbn.load_dataset("mpg"),
sbn.load_dataset("penguins"),
sbn.load_dataset("planets"),
sbn.load_dataset("seaice"),
sbn.load_dataset("taxis"),
sbn.load_dataset("tips"),
sbn.load_dataset("titanic"))

# %%
iris = sbn_datasets.iris

# %%
# Line chart
# sbn.kdeplot(iris)
# pyplot.hist(iris.sepal_width)
sbn.histplot(iris.sepal_length, kde=True)
sbn.histplot(iris.sepal_width, kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
diamonds = sbn_datasets.diamonds
diamonds.info()
sbn.histplot(diamonds.depth,color="red",kde=True)
# sbn.histplot(diamonds.cut)
# sbn.histplot(diamonds.color)
# sbn.histplot(diamonds.clarity)
# sbn.histplot(diamonds.depth)
# sbn.histplot(diamonds.table)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB
# <Axes: xlabel='depth', ylabel='Count'>

# %%
networks = sbn.load_dataset('brain_networks', header=[0,1,2], index_col=1)
networks.head()
# sbn.scatterplot(networks.network)
# Out:
# 1          network          1          2                     3             \
# 1             node          1          1                     1
# lh            hemi         rh         lh         rh         lh         rh
#  56.055744       0  92.031036   3.391576  38.659683  26.203819 -49.715569
#  55.547253       1  43.690075 -65.495987 -13.974523 -28.274963 -39.050129
#  60.997768       2  63.438793 -51.108582 -13.561346 -18.842947  -1.214659
#  18.514868       3  12.657158 -34.576603 -32.665958  -7.420454  17.119448
# -2.527392        4 -63.104668 -13.814151 -15.837989 -45.216927   3.483550
#
# 1                   4                     5             ...         16  \
# 1                   1                     1             ...          3
# lh                 lh         rh         lh         rh  ...         rh
#  56.055744  47.461037  26.746613 -35.898861  -1.889181  ...   0.607904
#  55.547253  -1.210660 -19.012897  19.568010  15.902983  ...  57.495071
# ...

# %%
# networks = sbn.load_dataset('brain_networks', header=[0,1,2], index_col=1)
# networks.to_csv("brain_networks.csv", index=False)
healthexp=sbn_datasets.healthexp
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
# networks.corr()

# sbn.clustermap(networks.corr(), cmap='coolwarm', center=0)
# Out:
# 1                   network         1         2                   3            \
# 1                      node         1         1                   1
# lh                     hemi        rh        lh        rh        lh        rh
# 1       1    lh
# network node hemi  1.000000  0.007432  0.001709  0.002201  0.000630 -0.000684
# 1       1    rh    0.007432  1.000000  0.013073  0.033733 -0.351509 -0.162006
# 2       1    lh    0.001709  0.013073  1.000000  0.813394 -0.006940 -0.039375
#              rh    0.002201  0.033733  0.813394  1.000000 -0.027324 -0.023608
# 3       1    lh    0.000630 -0.351509 -0.006940 -0.027324  1.000000  0.553183
# ...                     ...       ...       ...       ...       ...       ...
# 17      2    lh   -0.004456 -0.273370 -0.151724 -0.224447  0.026579 -0.056687
#              rh   -0.005218 -0.266456 -0.124508 -0.172704 -0.089109 -0.144020
#         3    lh   -0.008451 -0.174222 -0.179912 -0.250455 -0.012675 -0.047434
# ...

# %%
region1 = networks[('1','1','rh')]
region2 = networks['5','1','rh']
pyplot.figure(figsize=(8, 6))
# networks.columns
sbn.scatterplot(x=region1,y=region2)
# sbn.scatterplot(region1)

# networks.head()
# Out:
# <Axes: xlabel="('1', '1', 'rh')", ylabel="('5', '1', 'rh')">

# %%
sbn.scatterplot(x=region1, y=region2, hue=networks['grouping_variable'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\test\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grouping_variable'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...

# %%
networks.corr().columns
# Out:
# MultiIndex([('node', 'hemi',  'Unnamed: 0_level_2'),
#             (   '1',   'rh',  'Unnamed: 2_level_2'),
#             (   '1',   'lh',  'Unnamed: 3_level_2'),
#             (   '1',   'rh',  'Unnamed: 4_level_2'),
#             (   '1',   'lh',  'Unnamed: 5_level_2'),
#             (   '1',   'rh',  'Unnamed: 6_level_2'),
#             (   '1',   'lh',  'Unnamed: 7_level_2'),
#             (   '1',   'rh',  'Unnamed: 8_level_2'),
#             (   '1',   'lh',  'Unnamed: 9_level_2'),
#             (   '1',   'rh', 'Unnamed: 10_level_2'),
#             (   '1',   'lh', 'Unnamed: 11_level_2'),
#             (   '1',   'rh', 'Unnamed: 12_level_2'),
#             (   '2',   'lh', 'Unnamed: 13_level_2'),
#             (   '2',   'rh', 'Unnamed: 14_level_2'),
#             (   '1',   'lh', 'Unnamed: 15_level_2'),
#             (   '1',   'rh', 'Unnamed: 16_level_2'),
#             (   '2',   'lh', 'Unnamed: 17_level_2'),
#             (   '2',   'rh', 'Unnamed: 18_level_2'),
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Load the dataset
networks = sns.load_dataset('brain_networks', header=[0, 1, 2], index_col=1)

# Select a specific brain region's data
region_data = networks.iloc[:, 10]  # Arbitrary selection of a region

# Create a QQ plot
plt.figure(figsize=(8, 6))
stats.probplot(region_data.dropna(), dist="norm", plot=plt)

# Add title and labels
plt.title('QQ Plot of Brain Region Data (Region 10)')
plt.show()

# %%
health = sbn_datasets.healthexp
# health.info()
# sbn.lineplot(data=health, x=health.Spending_USD,y=health.Life_Expectancy)
# sbn.scatterplot(data=health, x=health.Spending_USD,y=health.Life_Expectancy)
sbn.lineplot(x='Year', y='Spending_USD', hue='Country', data=health)

# sbn.lineplot(x='Year', y='Spending_USD', data=health[health['Country'].isin(['United States', 'Germany', 'Japan'])])

# health['Country'].unique()
# Out:
# <Axes: xlabel='Year', ylabel='Spending_USD'>

# %%
# %matplotlib inline
health.columns
sbn.scatterplot(data=health, x=health.Spending_USD,y=health.Life_Expectancy)
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Life_Expectancy'>

# %%
health['Spending_USD'].corr(health['Life_Expectancy'])
# Out:
# 0.5794304588530952

# %%
health_data = health[['Spending_USD', 'Life_Expectancy']]
pyplot.figure(figsize=(6, 4))
sbn.heatmap(health_data.corr(),annot=True, cmap='coolwarm',center=0)
# Out:
# <Axes: >

# %%
from scipy.stats import probplot
# probplot(health[:10,:])
-
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
health_data.iloc[:,:1]
# Out:
#      Spending_USD
# 0         252.311
# 1         192.143
# 2         123.993
# 3         150.437
# 4         326.961
# ..            ...
# 269      6938.983
# 270      5468.418
# 271      5018.700
# 272      4665.641
# 273     11859.179
#
# [274 rows x 1 columns]

# %%
health_data
heal = health_data.iloc[:19,:]
heal
stats.probplot(heal.dropna())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 4
#       2 heal = health_data.iloc[:19,:]
#       3 heal
# ----> 4 stats.probplot(heal.dropna())
#
# File c:\users\test\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_morestats.py:622, in probplot(x, sparams, dist, fit, plot, rvalue)
#     619 osr = sort(x)
#     620 if fit:
#     621     # perform a linear least squares fit.
# --> 622     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     624 if plot is not None:
#     625     plot.plot(osm, osr, 'bo')
#
# File c:\users\test\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_stats_mstats_common.py:167, in linregress(x, y, alternative)
#     162 ymean = np.mean(y, None)
#     164 # Average sums of square differences from the mean
#     165 #   ssxm = mean( (x-mean(x))^2 )
# ...

# %%
stats.norm.rvs(size=1000)
# Out:
# array([ 6.16453781e-01,  9.26792821e-01,  6.26754273e-01,  6.56598507e-01,
#         2.34533789e-02, -3.60875280e-01, -8.55093309e-01,  6.08602288e-01,
#        -5.29814713e-01,  5.58182257e-02,  2.16096083e-01,  4.16375406e-01,
#        -7.87075434e-01, -7.42944497e-01, -7.25949306e-01,  7.55018257e-01,
#         6.83224142e-01,  9.72470516e-01, -1.09340018e+00,  1.88549684e-01,
#        -9.23882187e-01,  4.72989700e-01, -1.03850548e+00, -1.25971052e-02,
#        -3.57851971e-01,  2.27649413e-01, -1.34040722e+00,  1.68422402e+00,
#         4.76589086e-01, -1.30185225e+00, -1.82636930e+00,  1.84282490e+00,
#        -1.25682281e+00,  3.57992806e-01, -9.22321856e-01,  8.32012887e-01,
#         3.44916717e-02, -9.30679996e-01,  6.40480358e-01,  1.05348106e+00,
#         2.23183115e+00, -5.34941016e-02,  1.29371180e+00,  5.50978933e-01,
#         1.88682907e-01, -5.79729936e-01, -8.60760241e-01, -1.31027050e+00,
# ...

# %%
sbn_datasets.healthexp
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
# %matplotlib inline
healthexpec=sbn_datasets.healthexp
pyplot.figure(figsize=[10,5])
pyplot.subplot(1,2,1)
stats.probplot(iris.sepal_length,dist="norm", plot=pyplot);
sbn.histplot(iris.sepal_length,kde=True);

# %%
# from ggplot import ggplot, ggtitle, geom_point, aes
from plotnine import ggplot, ggtitle, geom_point, aes, labs, theme_minimal
# aes(x)
# (ggplot(data=iris + aes(x="sepal_length",y="sepal_width")) + geom_point())


# Create a scatter plot of petal length vs petal width
(ggplot(iris) +
 aes(x='sepal_length', y='sepal_width', color='species') +
 geom_point() +
 labs(title='Petal Length vs Petal Width', x='Petal Length', y='Petal Width') +
 theme_minimal()
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Set the theme to 'ggplot' style
# plt.style.use('ggplot')

# Create a scatterplot of petal length vs. petal width, colored by species
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species', palette='Set1')

# Add titles and labels
plt.title("Petal Length vs Petal Width by Species")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")

# Show the plot
plt.show()

# %%
sbn.pairplot(iris,hue="species", diag_kind="hist");

# %%
sbn.scatterplot(data=iris, x="sepal_width",y="petal_width", hue='species');

# %%
# iris[iris['sepal_width'] == 2.0]
# iris.where(iris['sepal_width'] == 2.0)
# iris.isnull().count()
# iris.count()
# iris.dropna()
iris.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris = sbn_datasets.iris
iris.isnull().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
iris.isnull().count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
iris = sbn.load_dataset("iris")
iris[iris.isna().any(axis=1)].count()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
mpg = sbn_datasets.mpg
mpg[mpg.isna().any(axis=1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl
